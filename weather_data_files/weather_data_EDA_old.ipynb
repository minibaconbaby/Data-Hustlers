# %%
conda install -c conda-forge geopandas
# Out:
# Channels:
#  - conda-forge
#  - defaults
# Platform: osx-arm64
# Collecting package metadata (repodata.json): done
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /opt/anaconda3
#
#   added / updated specs:
#     - geopandas
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     branca-0.7.2               |     pyhd8ed1ab_0          28 KB  conda-forge
#     cairo-1.16.0               |       h302bd0f_5         1.0 MB
#     certifi-2024.8.30          |     pyhd8ed1ab_0         160 KB  conda-forge
#     click-plugins-1.1.1        |             py_0           9 KB  conda-forge
#     cligj-0.7.2                |     pyhd8ed1ab_1          10 KB  conda-forge
#     conda-24.11.0              |  py312h81bd7bf_0         1.1 MB  conda-forge
#     fiona-1.9.5                |  py312hd77ebd4_0         905 KB
#     folium-0.18.0              |     pyhd8ed1ab_0          77 KB  conda-forge
#     fontconfig-2.14.2          |       h82840c6_0         232 KB  conda-forge
#     freexl-2.0.0               |       ha3de405_0          52 KB
#     gdal-3.6.2                 |  py312h5ed0132_4         1.6 MB
#     geopandas-0.14.4           |     pyhd8ed1ab_0           8 KB  conda-forge
#     geopandas-base-0.14.4      |     pyha770c72_0         997 KB  conda-forge
#     geos-3.9.1                 |       h9f76cd9_2         872 KB  conda-forge
#     geotiff-1.7.0              |       h41f0982_3         128 KB
#     hdf4-4.2.13                |    h0ef36ac_1005         875 KB  conda-forge
#     json-c-0.16                |       hc449e50_0          72 KB  conda-forge
#     kealib-1.5.0               |       hba2eb73_1         144 KB
#     libexpat-2.6.2             |       hebf3989_0          62 KB  conda-forge
#     libgdal-3.6.2              |       h0413ea8_4         8.3 MB
#     libkml-1.3.0               |       hc4d7c42_7         418 KB
#     libnetcdf-4.8.1            |       h0fce390_4         1.1 MB
#     libspatialite-5.1.0        |       h87e580a_0         3.8 MB
#     libsqlite-3.46.0           |       hfb93653_0         811 KB  conda-forge
#     libzip-1.10.1              |       ha0bc3c6_3         125 KB  conda-forge
#     libzlib-1.2.13             |       hfb2fe0b_6          46 KB  conda-forge
#     mapclassify-2.8.1          |     pyhd8ed1ab_0          57 KB  conda-forge
#     minizip-4.0.3              |       ha89c15f_0          84 KB
#     nspr-4.35                  |       hb7217d7_0         216 KB  conda-forge
#     nss-3.89.1                 |       h313beb8_0         1.8 MB
#     openssl-3.4.0              |       h39f12f2_0         2.8 MB  conda-forge
#     pixman-0.40.0              |       h27ca646_0         285 KB  conda-forge
#     poppler-22.12.0            |       h52f4003_3         1.6 MB
#     poppler-data-0.4.12        |       hd8ed1ab_0         2.2 MB  conda-forge
#     proj-9.3.1                 |       h805f6d4_0         2.8 MB
#     pyproj-3.6.1               |  py312h4d912e0_5         474 KB  conda-forge
#     python-3.12.2              |hdf0ec26_0_cpython        12.5 MB  conda-forge
#     python_abi-3.12            |          5_cp312           6 KB  conda-forge
#     qhull-2020.2               |       hc021e02_2         1.7 MB  conda-forge
#     shapely-2.0.5              |  py312ha8c8ce4_0         551 KB
#     tiledb-2.3.3               |       hb4a6b97_3         2.3 MB
#     uriparser-0.9.7            |       h13dd4ca_1          40 KB  conda-forge
#     xerces-c-3.2.4             |       h313beb8_1         2.2 MB
#     zlib-1.2.13                |       hfb2fe0b_6          76 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:        54.6 MB
#
# The following NEW packages will be INSTALLED:
#
#   branca             conda-forge/noarch::branca-0.7.2-pyhd8ed1ab_0
#   cairo              pkgs/main/osx-arm64::cairo-1.16.0-h302bd0f_5
#   click-plugins      conda-forge/noarch::click-plugins-1.1.1-py_0
#   cligj              conda-forge/noarch::cligj-0.7.2-pyhd8ed1ab_1
#   fiona              pkgs/main/osx-arm64::fiona-1.9.5-py312hd77ebd4_0
#   folium             conda-forge/noarch::folium-0.18.0-pyhd8ed1ab_0
#   fontconfig         conda-forge/osx-arm64::fontconfig-2.14.2-h82840c6_0
#   freexl             pkgs/main/osx-arm64::freexl-2.0.0-ha3de405_0
#   gdal               pkgs/main/osx-arm64::gdal-3.6.2-py312h5ed0132_4
#   geopandas          conda-forge/noarch::geopandas-0.14.4-pyhd8ed1ab_0
#   geopandas-base     conda-forge/noarch::geopandas-base-0.14.4-pyha770c72_0
#   geos               conda-forge/osx-arm64::geos-3.9.1-h9f76cd9_2
#   geotiff            pkgs/main/osx-arm64::geotiff-1.7.0-h41f0982_3
#   hdf4               conda-forge/osx-arm64::hdf4-4.2.13-h0ef36ac_1005
#   json-c             conda-forge/osx-arm64::json-c-0.16-hc449e50_0
#   kealib             pkgs/main/osx-arm64::kealib-1.5.0-hba2eb73_1
#   libexpat           conda-forge/osx-arm64::libexpat-2.6.2-hebf3989_0
#   libgdal            pkgs/main/osx-arm64::libgdal-3.6.2-h0413ea8_4
#   libkml             pkgs/main/osx-arm64::libkml-1.3.0-hc4d7c42_7
#   libnetcdf          pkgs/main/osx-arm64::libnetcdf-4.8.1-h0fce390_4
#   libspatialite      pkgs/main/osx-arm64::libspatialite-5.1.0-h87e580a_0
#   libsqlite          conda-forge/osx-arm64::libsqlite-3.46.0-hfb93653_0
#   libzip             conda-forge/osx-arm64::libzip-1.10.1-ha0bc3c6_3
#   libzlib            conda-forge/osx-arm64::libzlib-1.2.13-hfb2fe0b_6
#   mapclassify        conda-forge/noarch::mapclassify-2.8.1-pyhd8ed1ab_0
#   minizip            pkgs/main/osx-arm64::minizip-4.0.3-ha89c15f_0
#   nspr               conda-forge/osx-arm64::nspr-4.35-hb7217d7_0
#   nss                pkgs/main/osx-arm64::nss-3.89.1-h313beb8_0
#   pixman             conda-forge/osx-arm64::pixman-0.40.0-h27ca646_0
#   poppler            pkgs/main/osx-arm64::poppler-22.12.0-h52f4003_3
#   poppler-data       conda-forge/noarch::poppler-data-0.4.12-hd8ed1ab_0
#   proj               pkgs/main/osx-arm64::proj-9.3.1-h805f6d4_0
#   pyproj             conda-forge/osx-arm64::pyproj-3.6.1-py312h4d912e0_5
#   python_abi         conda-forge/osx-arm64::python_abi-3.12-5_cp312
#   qhull              conda-forge/osx-arm64::qhull-2020.2-hc021e02_2
#   shapely            pkgs/main/osx-arm64::shapely-2.0.5-py312ha8c8ce4_0
#   tiledb             pkgs/main/osx-arm64::tiledb-2.3.3-hb4a6b97_3
#   uriparser          conda-forge/osx-arm64::uriparser-0.9.7-h13dd4ca_1
#   xerces-c           pkgs/main/osx-arm64::xerces-c-3.2.4-h313beb8_1
#
# The following packages will be UPDATED:
#
#   conda              pkgs/main::conda-24.9.1-py312hca03da5~ --> conda-forge::conda-24.11.0-py312h81bd7bf_0
#   openssl              pkgs/main::openssl-3.0.15-h80987f9_0 --> conda-forge::openssl-3.4.0-h39f12f2_0
#   zlib                    pkgs/main::zlib-1.2.13-h18a0788_1 --> conda-forge::zlib-1.2.13-hfb2fe0b_6
#
# The following packages will be SUPERSEDED by a higher-priority channel:
#
#   certifi            pkgs/main/osx-arm64::certifi-2024.8.3~ --> conda-forge/noarch::certifi-2024.8.30-pyhd8ed1ab_0
#   python                pkgs/main::python-3.12.4-h99e199e_1 --> conda-forge::python-3.12.2-hdf0ec26_0_cpython
#
#
#
# Downloading and Extracting Packages:
# python-3.12.2        | 12.5 MB   |                                       |   0%
# libgdal-3.6.2        | 8.3 MB    |                                       |   0%
#
# libspatialite-5.1.0  | 3.8 MB    |                                       |   0%
#
#
# openssl-3.4.0        | 2.8 MB    |                                       |   0%
#
#
#
# proj-9.3.1           | 2.8 MB    |                                       |   0%
#
#
#
#
# tiledb-2.3.3         | 2.3 MB    |                                       |   0%
#
#
#
#
#
# poppler-data-0.4.12  | 2.2 MB    |                                       |   0%
#
#
#
#
#
#
# xerces-c-3.2.4       | 2.2 MB    |                                       |   0%
#
#
#
#
#
#
#
# nss-3.89.1           | 1.8 MB    |                                       |   0%
#
#
#
#
#
#
#
#
# qhull-2020.2         | 1.7 MB    |                                       |   0%
#
#
#
#
#
#
#
#
#
# gdal-3.6.2           | 1.6 MB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
# poppler-22.12.0      | 1.6 MB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
# conda-24.11.0        | 1.1 MB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
# libnetcdf-4.8.1      | 1.1 MB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
# cairo-1.16.0         | 1.0 MB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# geopandas-base-0.14. | 997 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# fiona-1.9.5          | 905 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# hdf4-4.2.13          | 875 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# geos-3.9.1           | 872 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libsqlite-3.46.0     | 811 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# shapely-2.0.5        | 551 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pyproj-3.6.1         | 474 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libkml-1.3.0         | 418 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
# libspatialite-5.1.0  | 3.8 MB    | 1                                     |   0%
# libgdal-3.6.2        | 8.3 MB    |                                       |   0%
#
# libspatialite-5.1.0  | 3.8 MB    | #2                                    |   3%
#
#
#
# proj-9.3.1           | 2.8 MB    | 2                                     |   1%
# libgdal-3.6.2        | 8.3 MB    | 6                                     |   2%
#
#
# openssl-3.4.0        | 2.8 MB    | 2                                     |   1%
#
# python-3.12.2        | 12.5 MB   |                                       |   0%
# libgdal-3.6.2        | 8.3 MB    | 9                                     |   3%
#
#
#
# proj-9.3.1           | 2.8 MB    | #6                                    |   5%
# libgdal-3.6.2        | 8.3 MB    | #8                                    |   5%
#
# libspatialite-5.1.0  | 3.8 MB    | #####3                                |  14%
#
#
# openssl-3.4.0        | 2.8 MB    | #6                                    |   4%
#
#
#
# python-3.12.2        | 12.5 MB   | 3                                     |   1%
#
#
#
# python-3.12.2        | 12.5 MB   | 6                                     |   2%
#
# libspatialite-5.1.0  | 3.8 MB    | ######6                               |  18%
# libgdal-3.6.2        | 8.3 MB    | ##3                                   |   6%
#
#
# openssl-3.4.0        | 2.8 MB    | ###                                   |   8%
#
# libspatialite-5.1.0  | 3.8 MB    | ########                              |  22%
# python-3.12.2        | 12.5 MB   | 8                                     |   2%
#
# libspatialite-5.1.0  | 3.8 MB    | #########                             |  25%
#
#
#
# proj-9.3.1           | 2.8 MB    | #######4                              |  20%
#
#
# openssl-3.4.0        | 2.8 MB    | #####5                                |  15%
# libgdal-3.6.2        | 8.3 MB    | ###8                                  |  11%
#
# libspatialite-5.1.0  | 3.8 MB    | ############5                         |  34%
#
#
#
# proj-9.3.1           | 2.8 MB    | ##############1                       |  38%
#
#
# python-3.12.2        | 12.5 MB   | #                                     |   3%
# libgdal-3.6.2        | 8.3 MB    | ####3                                 |  12%
#
# libspatialite-5.1.0  | 3.8 MB    | ##############2                       |  38%
#
#
#
# proj-9.3.1           | 2.8 MB    | #################2                    |  47%
#
#
# openssl-3.4.0        | 2.8 MB    | #########5                            |  26%
# libgdal-3.6.2        | 8.3 MB    | ####7                                 |  13%
#
# python-3.12.2        | 12.5 MB   | #8                                    |   5%
# libgdal-3.6.2        | 8.3 MB    | #####2                                |  14%
#
# libspatialite-5.1.0  | 3.8 MB    | #################2                    |  47%
#
#
# python-3.12.2        | 12.5 MB   | ##                                    |   6%
#
#
#
# proj-9.3.1           | 2.8 MB    | ###################7                  |  53%
#
#
# openssl-3.4.0        | 2.8 MB    | ###########5                          |  31%
# libgdal-3.6.2        | 8.3 MB    | #####6                                |  15%
#
# python-3.12.2        | 12.5 MB   | ##3                                   |   6%
#
#
# openssl-3.4.0        | 2.8 MB    | ############5                         |  34%
#
#
#
# proj-9.3.1           | 2.8 MB    | #####################8                |  59%
# libgdal-3.6.2        | 8.3 MB    | #####9                                |  16%
#
# libspatialite-5.1.0  | 3.8 MB    | ####################5                 |  56%
#
#
# python-3.12.2        | 12.5 MB   | ##5                                   |   7%
#
#
#
# proj-9.3.1           | 2.8 MB    | #######################7              |  64%
# libgdal-3.6.2        | 8.3 MB    | ######3                               |  17%
#
#
# openssl-3.4.0        | 2.8 MB    | ##############6                       |  40%
#
# libspatialite-5.1.0  | 3.8 MB    | #####################9                |  59%
#
#
#
# python-3.12.2        | 12.5 MB   | ##7                                   |   8%
#
#
# openssl-3.4.0        | 2.8 MB    | ###############6                      |  42%
#
#
#
# python-3.12.2        | 12.5 MB   | ##9                                   |   8%
#
# libspatialite-5.1.0  | 3.8 MB    | #######################3              |  63%
# libgdal-3.6.2        | 8.3 MB    | ######6                               |  18%
#
#
# python-3.12.2        | 12.5 MB   | ###1                                  |   9%
#
#
#
# proj-9.3.1           | 2.8 MB    | ############################7         |  78%
# libgdal-3.6.2        | 8.3 MB    | ######8                               |  19%
#
# libspatialite-5.1.0  | 3.8 MB    | ########################5             |  66%
#
#
# python-3.12.2        | 12.5 MB   | ###3                                  |   9%
#
#
#
# proj-9.3.1           | 2.8 MB    | ###############################6      |  86%
# libgdal-3.6.2        | 8.3 MB    | #######1                              |  19%
#
# libspatialite-5.1.0  | 3.8 MB    | #########################5            |  69%
#
#
# python-3.12.2        | 12.5 MB   | ###5                                  |  10%
#
#
#
# proj-9.3.1           | 2.8 MB    | #################################5    |  91%
# libgdal-3.6.2        | 8.3 MB    | #######3                              |  20%
#
# libspatialite-5.1.0  | 3.8 MB    | ##########################6           |  72%
#
#
#
# python-3.12.2        | 12.5 MB   | ###7                                  |  10%
#
#
# openssl-3.4.0        | 2.8 MB    | #####################2                |  57%
# libgdal-3.6.2        | 8.3 MB    | #######5                              |  20%
#
# python-3.12.2        | 12.5 MB   | ###9                                  |  11%
#
#
# openssl-3.4.0        | 2.8 MB    | ######################5               |  61%
# libgdal-3.6.2        | 8.3 MB    | #######7                              |  21%
#
#
#
#
# tiledb-2.3.3         | 2.3 MB    | 2                                     |   1%
#
# libspatialite-5.1.0  | 3.8 MB    | #############################3        |  79%
#
#
# python-3.12.2        | 12.5 MB   | ####2                                 |  12%
#
#
#
# proj-9.3.1           | 2.8 MB    | ##################################### | 100%
# libgdal-3.6.2        | 8.3 MB    | ########2                             |  22%
#
#
#
#
# tiledb-2.3.3         | 2.3 MB    | #9                                    |   5%
#
# libspatialite-5.1.0  | 3.8 MB    | ##############################4       |  82%
# libgdal-3.6.2        | 8.3 MB    | ########4                             |  23%
#
#
# python-3.12.2        | 12.5 MB   | ####4                                 |  12%
#
#
#
#
# tiledb-2.3.3         | 2.3 MB    | ###6                                  |  10%
#
# libspatialite-5.1.0  | 3.8 MB    | ###############################5      |  85%
# python-3.12.2        | 12.5 MB   | ####6                                 |  13%
#
#
# openssl-3.4.0        | 2.8 MB    | ##########################8           |  73%
#
# libspatialite-5.1.0  | 3.8 MB    | ################################5     |  88%
#
#
#
#
# tiledb-2.3.3         | 2.3 MB    | #####4                                |  15%
# python-3.12.2        | 12.5 MB   | ####8                                 |  13%
#
#
# openssl-3.4.0        | 2.8 MB    | ###########################8          |  75%
#
# libspatialite-5.1.0  | 3.8 MB    | #################################7    |  91%
#
#
#
#
# tiledb-2.3.3         | 2.3 MB    | #######1                              |  19%
# python-3.12.2        | 12.5 MB   | #####                                 |  14%
#
#
# openssl-3.4.0        | 2.8 MB    | ############################9         |  78%
#
#
#
#
# tiledb-2.3.3         | 2.3 MB    | ########8                             |  24%
#
# libspatialite-5.1.0  | 3.8 MB    | ##################################8   |  94%
# libgdal-3.6.2        | 8.3 MB    | #########5                            |  26%
#
#
# python-3.12.2        | 12.5 MB   | #####2                                |  14%
#
#
#
#
# tiledb-2.3.3         | 2.3 MB    | ##########3                           |  28%
#
# libspatialite-5.1.0  | 3.8 MB    | ###################################8  |  97%
# libgdal-3.6.2        | 8.3 MB    | #########8                            |  27%
#
#
# python-3.12.2        | 12.5 MB   | #####4                                |  15%
#
# libspatialite-5.1.0  | 3.8 MB    | ####################################8 |  99%
#
#
#
#
# tiledb-2.3.3         | 2.3 MB    | ###########8                          |  32%
#
#
# openssl-3.4.0        | 2.8 MB    | ################################      |  87%
# python-3.12.2        | 12.5 MB   | #####6                                |  15%
# libgdal-3.6.2        | 8.3 MB    | ##########5                           |  29%
#
#
#
#
# python-3.12.2        | 12.5 MB   | #####8                                |  16%
#
#
# openssl-3.4.0        | 2.8 MB    | #################################8    |  92%
#
# libspatialite-5.1.0  | 3.8 MB    | ##################################### | 100%
#
#
#
#
# tiledb-2.3.3         | 2.3 MB    | #################5                    |  47%
#
#
# openssl-3.4.0        | 2.8 MB    | ###################################1  |  95%
# python-3.12.2        | 12.5 MB   | ######1                               |  17%
#
#
#
#
#
# poppler-data-0.4.12  | 2.2 MB    | 2                                     |   1%
#
#
#
#
#
# poppler-data-0.4.12  | 2.2 MB    | ###3                                  |   9%
#
#
#
#
# tiledb-2.3.3         | 2.3 MB    | ###################4                  |  53%
# libgdal-3.6.2        | 8.3 MB    | ###########1                          |  30%
#
#
# python-3.12.2        | 12.5 MB   | ######3                               |  17%
#
#
#
#
#
# poppler-data-0.4.12  | 2.2 MB    | #####4                                |  15%
#
#
#
#
# tiledb-2.3.3         | 2.3 MB    | #####################2                |  57%
# libgdal-3.6.2        | 8.3 MB    | ###########4                          |  31%
#
#
#
#
#
# poppler-data-0.4.12  | 2.2 MB    | ##########3                           |  28%
#
#
# openssl-3.4.0        | 2.8 MB    | ##################################### | 100%
#
#
#
#
# tiledb-2.3.3         | 2.3 MB    | #######################1              |  63%
# python-3.12.2        | 12.5 MB   | ######6                               |  18%
#
#
#
#
#
# poppler-data-0.4.12  | 2.2 MB    | #############1                        |  36%
# libgdal-3.6.2        | 8.3 MB    | ############1                         |  33%
#
#
#
#
# python-3.12.2        | 12.5 MB   | ######8                               |  19%
#
#
#
#
#
# poppler-data-0.4.12  | 2.2 MB    | ################                      |  43%
# libgdal-3.6.2        | 8.3 MB    | ############3                         |  33%
#
#
#
#
# python-3.12.2        | 12.5 MB   | #######                               |  19%
#
#
#
#
# python-3.12.2        | 12.5 MB   | #######2                              |  20%
# libgdal-3.6.2        | 8.3 MB    | ############7                         |  34%
#
#
#
#
#
#
# xerces-c-3.2.4       | 2.2 MB    | 2                                     |   1%
#
#
#
#
#
# poppler-data-0.4.12  | 2.2 MB    | ##################8                   |  51%
#
#
#
#
# tiledb-2.3.3         | 2.3 MB    | ###############################8      |  86%
#
#
#
#
#
#
# xerces-c-3.2.4       | 2.2 MB    | ##1                                   |   6%
# python-3.12.2        | 12.5 MB   | #######5                              |  20%
#
#
#
#
#
# poppler-data-0.4.12  | 2.2 MB    | #####################1                |  57%
#
#
#
#
#
#
# xerces-c-3.2.4       | 2.2 MB    | ####2                                 |  11%
#
#
#
#
# tiledb-2.3.3         | 2.3 MB    | #################################7    |  91%
#
#
#
#
#
# poppler-data-0.4.12  | 2.2 MB    | #######################2              |  63%
# python-3.12.2        | 12.5 MB   | #######6                              |  21%
#
#
#
#
#
#
# xerces-c-3.2.4       | 2.2 MB    | ######8                               |  18%
#
#
#
#
#
# poppler-data-0.4.12  | 2.2 MB    | #########################5            |  69%
#
#
#
#
# tiledb-2.3.3         | 2.3 MB    | ###################################7  |  97%
# python-3.12.2        | 12.5 MB   | #######8                              |  21%
#
#
#
#
#
#
# xerces-c-3.2.4       | 2.2 MB    | ########6                             |  23%
#
#
#
#
#
# poppler-data-0.4.12  | 2.2 MB    | ###########################6          |  75%
#
#
#
#
# tiledb-2.3.3         | 2.3 MB    | ##################################### | 100%
# python-3.12.2        | 12.5 MB   | ########1                             |  22%
#
#
#
#
#
# poppler-data-0.4.12  | 2.2 MB    | ##############################7       |  83%
#
#
#
#
#
#
# xerces-c-3.2.4       | 2.2 MB    | ############6                         |  34%
#
#
#
#
#
#
# xerces-c-3.2.4       | 2.2 MB    | ################                      |  43%
#
#
#
#
#
# poppler-data-0.4.12  | 2.2 MB    | #################################     |  89%
# python-3.12.2        | 12.5 MB   | ########2                             |  22%
#
#
#
#
#
#
#
# nss-3.89.1           | 1.8 MB    | 3                                     |   1%
#
#
#
#
#
# poppler-data-0.4.12  | 2.2 MB    | ###################################3  |  96%
#
#
#
#
#
#
# xerces-c-3.2.4       | 2.2 MB    | ##################6                   |  50%
# libgdal-3.6.2        | 8.3 MB    | ##############7                       |  40%
#
#
#
#
#
#
#
# python-3.12.2        | 12.5 MB   | ########4                             |  23%
#
#
#
#
#
#
# xerces-c-3.2.4       | 2.2 MB    | #####################                 |  57%
#
#
#
#
#
#
#
# python-3.12.2        | 12.5 MB   | ########5                             |  23%
# libgdal-3.6.2        | 8.3 MB    | ###############                       |  41%
#
#
#
#
#
#
# xerces-c-3.2.4       | 2.2 MB    | ########################7             |  67%
#
#
#
#
#
#
#
# python-3.12.2        | 12.5 MB   | ########7                             |  24%
# libgdal-3.6.2        | 8.3 MB    | ###############3                      |  41%
#
#
#
#
#
# poppler-data-0.4.12  | 2.2 MB    | ##################################### | 100%
#
#
#
#
#
#
# xerces-c-3.2.4       | 2.2 MB    | ############################1         |  76%
#
#
#
#
#
#
#
# python-3.12.2        | 12.5 MB   | ########8                             |  24%
#
#
#
#
#
#
#
#
# qhull-2020.2         | 1.7 MB    | 3                                     |   1%
# libgdal-3.6.2        | 8.3 MB    | ###############5                      |  42%
#
#
#
#
#
#
# xerces-c-3.2.4       | 2.2 MB    | ###############################       |  84%
#
#
#
#
#
#
#
# nss-3.89.1           | 1.8 MB    | ##########                            |  27%
#
#
#
#
#
#
#
#
# python-3.12.2        | 12.5 MB   | #########                             |  24%
# libgdal-3.6.2        | 8.3 MB    | ###############8                      |  43%
#
#
#
#
#
#
#
#
# qhull-2020.2         | 1.7 MB    | ####6                                 |  13%
#
#
#
#
#
#
# xerces-c-3.2.4       | 2.2 MB    | #################################9    |  92%
#
#
#
#
#
#
#
#
# qhull-2020.2         | 1.7 MB    | #######3                              |  20%
# libgdal-3.6.2        | 8.3 MB    | ################2                     |  44%
#
#
#
#
#
#
# xerces-c-3.2.4       | 2.2 MB    | ####################################2 |  98%
#
#
#
#
#
#
#
# python-3.12.2        | 12.5 MB   | #########1                            |  25%
#
#
#
#
#
#
#
#
# qhull-2020.2         | 1.7 MB    | ##########3                           |  28%
# libgdal-3.6.2        | 8.3 MB    | ################5                     |  45%
#
#
#
#
#
#
#
# python-3.12.2        | 12.5 MB   | #########5                            |  26%
#
#
#
#
#
#
#
#
#
# gdal-3.6.2           | 1.6 MB    | 3                                     |   1%
#
#
#
#
#
#
#
#
# qhull-2020.2         | 1.7 MB    | ############6                         |  34%
#
#
#
#
#
#
# xerces-c-3.2.4       | 2.2 MB    | ##################################### | 100%
# libgdal-3.6.2        | 8.3 MB    | ################9                     |  46%
#
#
#
#
#
#
#
# python-3.12.2        | 12.5 MB   | #########7                            |  26%
#
#
#
#
#
#
#
#
#
# gdal-3.6.2           | 1.6 MB    | ###1                                  |   9%
#
#
#
#
#
#
#
#
# qhull-2020.2         | 1.7 MB    | ##############9                       |  41%
# libgdal-3.6.2        | 8.3 MB    | #################1                    |  46%
#
#
#
#
#
#
#
#
#
# python-3.12.2        | 12.5 MB   | #########9                            |  27%
#
#
#
#
#
#
#
# nss-3.89.1           | 1.8 MB    | ######################2               |  60%
#
#
#
#
#
#
#
#
#
# gdal-3.6.2           | 1.6 MB    | ##########6                           |  29%
#
#
#
#
#
#
#
#
# qhull-2020.2         | 1.7 MB    | #################3                    |  47%
# python-3.12.2        | 12.5 MB   | ##########1                           |  27%
#
#
#
#
#
#
#
# nss-3.89.1           | 1.8 MB    | ########################4             |  66%
#
#
#
#
#
#
#
#
#
# gdal-3.6.2           | 1.6 MB    | ##############8                       |  40%
#
#
#
#
#
#
#
#
# python-3.12.2        | 12.5 MB   | ##########3                           |  28%
# libgdal-3.6.2        | 8.3 MB    | #################8                    |  48%
#
#
#
#
#
#
#
# nss-3.89.1           | 1.8 MB    | ##########################3           |  71%
#
#
#
#
#
#
#
#
#
# gdal-3.6.2           | 1.6 MB    | ##################4                   |  50%
#
#
#
#
#
#
#
#
# qhull-2020.2         | 1.7 MB    | #####################3                |  58%
# python-3.12.2        | 12.5 MB   | ##########5                           |  28%
#
#
#
#
#
#
#
#
#
# gdal-3.6.2           | 1.6 MB    | #####################6                |  58%
#
#
#
#
#
#
#
# nss-3.89.1           | 1.8 MB    | ############################2         |  76%
#
#
#
#
#
#
#
#
# qhull-2020.2         | 1.7 MB    | ######################9               |  62%
#
#
#
#
#
#
#
#
#
# gdal-3.6.2           | 1.6 MB    | ###########################3          |  74%
#
#
#
#
#
#
#
#
# qhull-2020.2         | 1.7 MB    | ########################6             |  67%
# libgdal-3.6.2        | 8.3 MB    | ##################5                   |  50%
#
#
#
#
#
#
#
# python-3.12.2        | 12.5 MB   | ##########7                           |  29%
#
#
#
#
#
#
#
#
#
# gdal-3.6.2           | 1.6 MB    | ################################2     |  87%
#
#
#
#
#
#
#
#
# qhull-2020.2         | 1.7 MB    | ##########################3           |  71%
#
#
#
#
#
#
#
# nss-3.89.1           | 1.8 MB    | ###############################7      |  86%
# python-3.12.2        | 12.5 MB   | ##########9                           |  30%
#
#
#
#
#
#
#
#
#
# gdal-3.6.2           | 1.6 MB    | ####################################5 |  99%
#
#
#
#
#
#
#
#
# qhull-2020.2         | 1.7 MB    | ############################3         |  77%
#
#
#
#
#
#
#
# nss-3.89.1           | 1.8 MB    | #################################2    |  90%
# python-3.12.2        | 12.5 MB   | ###########1                          |  30%
#
#
#
#
#
#
#
#
#
# gdal-3.6.2           | 1.6 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
# qhull-2020.2         | 1.7 MB    | #############################9        |  81%
#
#
#
#
#
#
#
# nss-3.89.1           | 1.8 MB    | ##################################8   |  94%
# python-3.12.2        | 12.5 MB   | ###########3                          |  31%
#
#
#
#
#
#
#
#
#
#
# poppler-22.12.0      | 1.6 MB    | 3                                     |   1%
#
#
#
#
#
#
#
#
# qhull-2020.2         | 1.7 MB    | #################################6    |  91%
# python-3.12.2        | 12.5 MB   | ###########4                          |  31%
#
#
#
#
#
#
#
# nss-3.89.1           | 1.8 MB    | ##################################### | 100%
#
#
#
#
#
#
#
# nss-3.89.1           | 1.8 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
# poppler-22.12.0      | 1.6 MB    | ######2                               |  17%
#
#
#
#
#
#
#
#
# qhull-2020.2         | 1.7 MB    | ####################################3 |  98%
# python-3.12.2        | 12.5 MB   | ###########6                          |  32%
#
#
#
#
#
#
#
#
#
#
# poppler-22.12.0      | 1.6 MB    | #########9                            |  27%
# python-3.12.2        | 12.5 MB   | ###########9                          |  32%
#
#
#
#
#
#
#
#
#
#
# poppler-22.12.0      | 1.6 MB    | ###############1                      |  41%
#
#
#
#
#
#
#
#
#
#
#
#
# libnetcdf-4.8.1      | 1.1 MB    | 5                                     |   1%
#
#
#
#
#
#
#
#
# qhull-2020.2         | 1.7 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
# libnetcdf-4.8.1      | 1.1 MB    | ##1                                   |   6%
# libgdal-3.6.2        | 8.3 MB    | ####################8                 |  56%
#
#
#
#
#
#
#
#
#
#
# python-3.12.2        | 12.5 MB   | ############                          |  33%
#
#
#
#
#
#
#
#
#
#
#
# conda-24.11.0        | 1.1 MB    | 5                                     |   1%
#
#
#
#
#
#
#
#
#
#
# poppler-22.12.0      | 1.6 MB    | ########################              |  65%
#
#
#
#
#
#
#
#
#
#
#
#
# python-3.12.2        | 12.5 MB   | ############3                         |  33%
# libgdal-3.6.2        | 8.3 MB    | #####################2                |  58%
#
#
#
#
#
#
#
#
#
#
#
# conda-24.11.0        | 1.1 MB    | ####1                                 |  11%
#
#
#
#
#
#
#
#
#
#
# poppler-22.12.0      | 1.6 MB    | ############################1         |  76%
#
#
#
#
#
#
#
#
#
#
#
#
# libnetcdf-4.8.1      | 1.1 MB    | #########8                            |  27%
# python-3.12.2        | 12.5 MB   | ############5                         |  34%
#
#
#
#
#
#
#
#
#
#
#
# conda-24.11.0        | 1.1 MB    | ########2                             |  22%
#
#
#
#
#
#
#
#
#
#
# poppler-22.12.0      | 1.6 MB    | ################################5     |  88%
#
#
#
#
#
#
#
#
#
#
#
#
# libnetcdf-4.8.1      | 1.1 MB    | #############1                        |  36%
#
#
#
#
#
#
#
#
#
#
#
# python-3.12.2        | 12.5 MB   | ############6                         |  34%
# libgdal-3.6.2        | 8.3 MB    | #####################9                |  59%
#
#
#
#
#
#
#
#
#
#
#
#
# libnetcdf-4.8.1      | 1.1 MB    | ###############9                      |  43%
#
#
#
#
#
#
#
#
#
#
# poppler-22.12.0      | 1.6 MB    | ####################################2 |  98%
#
#
#
#
#
#
#
#
#
#
#
# conda-24.11.0        | 1.1 MB    | ########################2             |  66%
#
#
#
#
#
#
#
#
#
#
# poppler-22.12.0      | 1.6 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
# libnetcdf-4.8.1      | 1.1 MB    | ###################2                  |  52%
# python-3.12.2        | 12.5 MB   | ############9                         |  35%
#
#
#
#
#
#
#
#
#
#
#
# conda-24.11.0        | 1.1 MB    | ################################5     |  88%
#
#
#
#
#
#
#
#
#
#
#
#
# libnetcdf-4.8.1      | 1.1 MB    | #####################9                |  59%
#
#
#
#
#
#
#
#
#
#
#
#
#
# cairo-1.16.0         | 1.0 MB    | 5                                     |   2%
# python-3.12.2        | 12.5 MB   | #############                         |  35%
#
#
#
#
#
#
#
#
#
#
#
#
# libnetcdf-4.8.1      | 1.1 MB    | #########################2            |  68%
#
#
#
#
#
#
#
#
#
#
#
#
#
# python-3.12.2        | 12.5 MB   | #############2                        |  36%
# libgdal-3.6.2        | 8.3 MB    | ######################8               |  62%
#
#
#
#
#
#
#
#
#
#
#
# conda-24.11.0        | 1.1 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
# cairo-1.16.0         | 1.0 MB    | ##########7                           |  29%
#
#
#
#
#
#
#
#
#
#
#
#
# libnetcdf-4.8.1      | 1.1 MB    | ############################          |  76%
# python-3.12.2        | 12.5 MB   | #############4                        |  36%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# geopandas-base-0.14. | 997 KB    | 5                                     |   2%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# geopandas-base-0.14. | 997 KB    | ###########8                          |  32%
#
#
#
#
#
#
#
#
#
#
#
#
#
# cairo-1.16.0         | 1.0 MB    | ##################1                   |  49%
#
#
#
#
#
#
#
#
#
#
#
#
# libnetcdf-4.8.1      | 1.1 MB    | ##############################7       |  83%
#
#
#
#
#
#
#
#
#
#
#
#
#
# cairo-1.16.0         | 1.0 MB    | ######################                |  60%
#
#
#
#
#
#
#
#
#
#
#
#
# python-3.12.2        | 12.5 MB   | #############6                        |  37%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# geopandas-base-0.14. | 997 KB    | ##############2                       |  39%
# python-3.12.2        | 12.5 MB   | ##############1                       |  38%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# hdf4-4.2.13          | 875 KB    | 6                                     |   2%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# geopandas-base-0.14. | 997 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
# libnetcdf-4.8.1      | 1.1 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
# libnetcdf-4.8.1      | 1.1 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
# cairo-1.16.0         | 1.0 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
# cairo-1.16.0         | 1.0 MB    | ##################################### | 100%
# libgdal-3.6.2        | 8.3 MB    | ########################6             |  67%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# hdf4-4.2.13          | 875 KB    | ##############2                       |  38%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# fiona-1.9.5          | 905 KB    | 6                                     |   2%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# geos-3.9.1           | 872 KB    | 6                                     |   2%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# hdf4-4.2.13          | 875 KB    | ###########################7          |  75%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# fiona-1.9.5          | 905 KB    | ###2                                  |   9%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# python-3.12.2        | 12.5 MB   | ##############4                       |  39%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# fiona-1.9.5          | 905 KB    | #####8                                |  16%
# libgdal-3.6.2        | 8.3 MB    | ########################9             |  67%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# python-3.12.2        | 12.5 MB   | ##############6                       |  40%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# geos-3.9.1           | 872 KB    | ##########1                           |  28%
# libgdal-3.6.2        | 8.3 MB    | #########################3            |  68%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# hdf4-4.2.13          | 875 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# fiona-1.9.5          | 905 KB    | ###########################4          |  74%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libsqlite-3.46.0     | 811 KB    | 7                                     |   2%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# geos-3.9.1           | 872 KB    | ##############9                       |  40%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libsqlite-3.46.0     | 811 KB    | #############1                        |  36%
# python-3.12.2        | 12.5 MB   | ##############9                       |  40%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# fiona-1.9.5          | 905 KB    | ###################################3  |  95%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# geos-3.9.1           | 872 KB    | ###################                   |  51%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libsqlite-3.46.0     | 811 KB    | #########################5            |  69%
# libgdal-3.6.2        | 8.3 MB    | ##########################3           |  71%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libsqlite-3.46.0     | 811 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# python-3.12.2        | 12.5 MB   | ###############4                      |  42%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# geos-3.9.1           | 872 KB    | ###############################2      |  84%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# shapely-2.0.5        | 551 KB    | #                                     |   3%
# libgdal-3.6.2        | 8.3 MB    | ##########################7           |  72%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pyproj-3.6.1         | 474 KB    | #2                                    |   3%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# shapely-2.0.5        | 551 KB    | #######5                              |  20%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pyproj-3.6.1         | 474 KB    | ##################7                   |  51%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pyproj-3.6.1         | 474 KB    | ####################################2 |  98%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# python-3.12.2        | 12.5 MB   | ###############7                      |  43%
# libgdal-3.6.2        | 8.3 MB    | ###########################           |  73%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pyproj-3.6.1         | 474 KB    | ##################################### | 100%
# python-3.12.2        | 12.5 MB   | ################                      |  43%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libkml-1.3.0         | 418 KB    | #4                                    |   4%
# libgdal-3.6.2        | 8.3 MB    | ###########################6          |  75%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libkml-1.3.0         | 418 KB    | #########9                            |  27%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# shapely-2.0.5        | 551 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# shapely-2.0.5        | 551 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# python-3.12.2        | 12.5 MB   | ################2                     |  44% [A
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# geos-3.9.1           | 872 KB    | ##################################### | 100%
# libgdal-3.6.2        | 8.3 MB    | ############################          |  76%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# python-3.12.2        | 12.5 MB   | ################4                     |  45%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libkml-1.3.0         | 418 KB    | ############################3         |  77%
# python-3.12.2        | 12.5 MB   | ################8                     |  45%
# libgdal-3.6.2        | 8.3 MB    | ############################7         |  78%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libkml-1.3.0         | 418 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libkml-1.3.0         | 418 KB    | ##################################### | 100%
# python-3.12.2        | 12.5 MB   | #################                     |  46%
# python-3.12.2        | 12.5 MB   | #################2                    |  47%
# python-3.12.2        | 12.5 MB   | #################5                    |  47%
# python-3.12.2        | 12.5 MB   | #################9                    |  49%
# python-3.12.2        | 12.5 MB   | ##################2                   |  49%
# python-3.12.2        | 12.5 MB   | ##################7                   |  51%
# python-3.12.2        | 12.5 MB   | ###################2                  |  52%
# python-3.12.2        | 12.5 MB   | ###################6                  |  53%
# python-3.12.2        | 12.5 MB   | ####################1                 |  54%
# python-3.12.2        | 12.5 MB   | ####################6                 |  56%
# python-3.12.2        | 12.5 MB   | #####################8                |  59%
# python-3.12.2        | 12.5 MB   | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
#
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install geopandas
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting geopandas
#   Downloading geopandas-1.0.1-py3-none-any.whl (323 kB)
#      |████████████████████████████████| 323 kB 3.6 MB/s eta 0:00:01
# Collecting pandas>=1.4.0
#   Downloading pandas-2.2.3-cp39-cp39-macosx_11_0_arm64.whl (11.3 MB)
#      |████████████████████████████████| 11.3 MB 363 kB/s eta 0:00:01     |███████████████████████████████▊| 11.2 MB 888 kB/s eta 0:00:01
# Collecting numpy>=1.22
#   Downloading numpy-2.0.2-cp39-cp39-macosx_11_0_arm64.whl (13.7 MB)
#      |████████████████████████████████| 13.7 MB 4.2 MB/s eta 0:00:01
# Collecting shapely>=2.0.0
#   Downloading shapely-2.0.6-cp39-cp39-macosx_11_0_arm64.whl (1.3 MB)
#      |████████████████████████████████| 1.3 MB 3.5 MB/s eta 0:00:01
# Collecting pyogrio>=0.7.2
#   Downloading pyogrio-0.10.0-cp39-cp39-macosx_12_0_arm64.whl (15.1 MB)
#      |████████████████████████████████| 15.1 MB 62.6 MB/s eta 0:00:01
# Requirement already satisfied: packaging in /Users/catherineye/Library/Python/3.9/lib/python/site-packages (from geopandas) (24.2)
# Collecting pyproj>=3.3.0
#   Downloading pyproj-3.6.1-cp39-cp39-macosx_11_0_arm64.whl (4.9 MB)
#      |████████████████████████████████| 4.9 MB 3.9 MB/s eta 0:00:01
# Collecting pytz>=2020.1
#   Downloading pytz-2024.2-py2.py3-none-any.whl (508 kB)
#      |████████████████████████████████| 508 kB 4.5 MB/s eta 0:00:01
# Collecting tzdata>=2022.7
#   Downloading tzdata-2024.2-py2.py3-none-any.whl (346 kB)
#      |████████████████████████████████| 346 kB 4.0 MB/s eta 0:00:01
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/catherineye/Library/Python/3.9/lib/python/site-packages (from pandas>=1.4.0->geopandas) (2.9.0.post0)
# Collecting certifi
#   Downloading certifi-2024.8.30-py3-none-any.whl (167 kB)
#      |████████████████████████████████| 167 kB 4.7 MB/s eta 0:00:01
# Requirement already satisfied: six>=1.5 in /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/site-packages (from python-dateutil>=2.8.2->pandas>=1.4.0->geopandas) (1.15.0)
# Installing collected packages: tzdata, pytz, numpy, certifi, shapely, pyproj, pyogrio, pandas, geopandas
# Successfully installed certifi-2024.8.30 geopandas-1.0.1 numpy-2.0.2 pandas-2.2.3 pyogrio-0.10.0 pyproj-3.6.1 pytz-2024.2 shapely-2.0.6 tzdata-2024.2
# WARNING: You are using pip version 21.2.4; however, version 24.3.1 is available.
# You should consider upgrading via the '/Library/Developer/CommandLineTools/usr/bin/python3 -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install matplotlib
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting matplotlib
#   Downloading matplotlib-3.9.3-cp39-cp39-macosx_11_0_arm64.whl (7.8 MB)
#      |████████████████████████████████| 7.8 MB 3.4 MB/s eta 0:00:01
# Collecting pyparsing>=2.3.1
#   Downloading pyparsing-3.2.0-py3-none-any.whl (106 kB)
#      |████████████████████████████████| 106 kB 5.0 MB/s eta 0:00:01
# Collecting fonttools>=4.22.0
#   Downloading fonttools-4.55.0-cp39-cp39-macosx_10_9_universal2.whl (2.8 MB)
#      |████████████████████████████████| 2.8 MB 4.0 MB/s eta 0:00:01
# Collecting contourpy>=1.0.1
#   Downloading contourpy-1.3.0-cp39-cp39-macosx_11_0_arm64.whl (249 kB)
#      |████████████████████████████████| 249 kB 4.0 MB/s eta 0:00:01
# Collecting pillow>=8
#   Downloading pillow-11.0.0-cp39-cp39-macosx_11_0_arm64.whl (3.0 MB)
#      |████████████████████████████████| 3.0 MB 3.4 MB/s eta 0:00:01
# Requirement already satisfied: python-dateutil>=2.7 in /Users/catherineye/Library/Python/3.9/lib/python/site-packages (from matplotlib) (2.9.0.post0)
# Collecting cycler>=0.10
#   Downloading cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Requirement already satisfied: packaging>=20.0 in /Users/catherineye/Library/Python/3.9/lib/python/site-packages (from matplotlib) (24.2)
# Requirement already satisfied: numpy>=1.23 in /Users/catherineye/Library/Python/3.9/lib/python/site-packages (from matplotlib) (2.0.2)
# Collecting importlib-resources>=3.2.0
#   Downloading importlib_resources-6.4.5-py3-none-any.whl (36 kB)
# Collecting kiwisolver>=1.3.1
#   Downloading kiwisolver-1.4.7-cp39-cp39-macosx_11_0_arm64.whl (64 kB)
#      |████████████████████████████████| 64 kB 5.1 MB/s eta 0:00:011
# Requirement already satisfied: zipp>=3.1.0 in /Users/catherineye/Library/Python/3.9/lib/python/site-packages (from importlib-resources>=3.2.0->matplotlib) (3.21.0)
# Requirement already satisfied: six>=1.5 in /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/site-packages (from python-dateutil>=2.7->matplotlib) (1.15.0)
# Installing collected packages: pyparsing, pillow, kiwisolver, importlib-resources, fonttools, cycler, contourpy, matplotlib
# Successfully installed contourpy-1.3.0 cycler-0.12.1 fonttools-4.55.0 importlib-resources-6.4.5 kiwisolver-1.4.7 matplotlib-3.9.3 pillow-11.0.0 pyparsing-3.2.0
# WARNING: You are using pip version 21.2.4; however, version 24.3.1 is available.
# You should consider upgrading via the '/Library/Developer/CommandLineTools/usr/bin/python3 -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install seaborn
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting seaborn
#   Downloading seaborn-0.13.2-py3-none-any.whl (294 kB)
#      |████████████████████████████████| 294 kB 1.1 MB/s eta 0:00:01
# Requirement already satisfied: pandas>=1.2 in /Users/catherineye/Library/Python/3.9/lib/python/site-packages (from seaborn) (2.2.3)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in /Users/catherineye/Library/Python/3.9/lib/python/site-packages (from seaborn) (3.9.3)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in /Users/catherineye/Library/Python/3.9/lib/python/site-packages (from seaborn) (2.0.2)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/catherineye/Library/Python/3.9/lib/python/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.7)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/catherineye/Library/Python/3.9/lib/python/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.3.0)
# Requirement already satisfied: importlib-resources>=3.2.0 in /Users/catherineye/Library/Python/3.9/lib/python/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (6.4.5)
# Requirement already satisfied: pillow>=8 in /Users/catherineye/Library/Python/3.9/lib/python/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (11.0.0)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/catherineye/Library/Python/3.9/lib/python/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: packaging>=20.0 in /Users/catherineye/Library/Python/3.9/lib/python/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (24.2)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/catherineye/Library/Python/3.9/lib/python/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.55.0)
# Requirement already satisfied: cycler>=0.10 in /Users/catherineye/Library/Python/3.9/lib/python/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/catherineye/Library/Python/3.9/lib/python/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.2.0)
# Requirement already satisfied: zipp>=3.1.0 in /Users/catherineye/Library/Python/3.9/lib/python/site-packages (from importlib-resources>=3.2.0->matplotlib!=3.6.1,>=3.4->seaborn) (3.21.0)
# Requirement already satisfied: tzdata>=2022.7 in /Users/catherineye/Library/Python/3.9/lib/python/site-packages (from pandas>=1.2->seaborn) (2024.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/catherineye/Library/Python/3.9/lib/python/site-packages (from pandas>=1.2->seaborn) (2024.2)
# Requirement already satisfied: six>=1.5 in /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.15.0)
# Installing collected packages: seaborn
# Successfully installed seaborn-0.13.2
# WARNING: You are using pip version 21.2.4; however, version 24.3.1 is available.
# You should consider upgrading via the '/Library/Developer/CommandLineTools/usr/bin/python3 -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %%
import geopandas as gpd
import pandas as pd
import os

import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# Import Datasets

# %%
# Define the directory where the CSV files are saved
save_directory = "clean_data"

# List of filenames to open
filenames = [
    "geocoded_df.csv",
    "neighbourhoods_df_cleaned.csv",
    "parks_df.csv",
    "schools_df.csv",
    "filtered_gdf.csv"
]

# Dictionary to store the DataFrames
dataframes = {}

# Loop through the filenames and read the CSVs into DataFrames
for filename in filenames:
    file_path = os.path.join(save_directory, filename)
    dataframes[filename] = pd.read_csv(file_path)


# Access the loaded DataFrames by filename (example)
geocoded_df = dataframes.get("geocoded_df.csv") # development applications
neighbourhoods_df_profiles = dataframes.get("neighbourhoods_df_cleaned.csv") # geometry shape file
parks_df = dataframes.get("parks_df.csv") # parks data
schools_df = dataframes.get("schools_df.csv") # school data
filtered_gdf = dataframes.get("filtered_gdf.csv") # homeless shelter data
# neighbourhoods_df_pivoted = dataframes.get("pivoted_neighbourhood_profiles.csv") # neighborhood profiles with income
neighbourhoods_df_pivoted = pd.read_csv('pivoted_neighbourhood_profiles.csv')

# %%
PollinateTO_df = pd.read_csv('clean_data/PollinateTO_cleaned.csv')

# %%
print(PollinateTO_df.columns)
# Out:
# Index(['_id', 'ID', 'YEAR_FUNDED', 'GROUP_NAME', 'PROJECT_NAME', 'GARDEN_TYPE',
#        'NUMBER_OF_GARDENS', 'ESTIMATED_GARDEN_SIZE', 'NEIGHBOURHOOD_NUMBER',
#        'NIA_OR_EN', 'PRIMARY_LOCATION_NAME', 'PRIMARY_GARDEN_ADDRESS',
#        'POSTAL_CODE', 'IS_INDIGENOUS_GARDEN', 'WARD_NAME', 'WARD_NUMBER',
#        'geometry'],
#       dtype='object')

# %% [markdown]
# ## Load Weather Data

# %%
weather_df = pd.read_csv('raw_data/weather_df.csv')

# %%
# Count entries of PollinateTO projects for each funded year
year_counts = PollinateTO_df['YEAR_FUNDED'].value_counts()

print(year_counts)
# Out:
# YEAR_FUNDED
# 2023    44
# 2022    40
# 2020    33
# 2021    32
# Name: count, dtype: int64

# %% [markdown]
# We can see that there are more projects funded as each year progresses. Let's examine this and see if weather played a role.
#
# The weather variables that we want to focus on are:
# - Annual average temperature: to observe general climate trends over years
# - Annual precipitation: to see if wetter or drier years align with more gardens funded

# %%
# Prepare yearly weather aggregates

# Count the number of gardens funded each year
gardens_funded = PollinateTO_df['YEAR_FUNDED'].value_counts().sort_index()
gardens_funded.name = 'gardens_funded'

# Merge weather and garden data on 'year'
merged_df = pd.merge(weather_df, gardens_funded, left_on='Year', right_index=True)

print(merged_df)
# Out:
#       Longitude (x)  Latitude (y)  Station Name  Climate ID  Year  Month  Day  \
# 365           -79.4         43.67  TORONTO CITY     6158355  2020      1    1
# 366           -79.4         43.67  TORONTO CITY     6158355  2020      1    2
# 367           -79.4         43.67  TORONTO CITY     6158355  2020      1    3
# 368           -79.4         43.67  TORONTO CITY     6158355  2020      1    4
# 369           -79.4         43.67  TORONTO CITY     6158355  2020      1    5
# ...             ...           ...           ...         ...   ...    ...  ...
# 1821          -79.4         43.67  TORONTO CITY     6158355  2022     12   27
# 1822          -79.4         43.67  TORONTO CITY     6158355  2022     12   28
# 1823          -79.4         43.67  TORONTO CITY     6158355  2022     12   29
# 1824          -79.4         43.67  TORONTO CITY     6158355  2022     12   30
# 1825          -79.4         43.67  TORONTO CITY     6158355  2022     12   31
#
#       Data Quality  Max Temp (°C)  Min Temp (°C)  ...  Heat Deg Days (°C)  \
# 365            NaN            1.0           -1.2  ...                18.1
# 366            NaN            6.2            0.9  ...                14.4
# 367            NaN            7.7            3.6  ...                12.3
# 368            NaN            3.6            0.3  ...                16.0
# 369            NaN            1.9           -1.2  ...                17.7
# ...            ...            ...            ...  ...                 ...
# 1821           NaN            0.0           -5.7  ...                20.8
# 1822           NaN            4.9           -0.2  ...                15.7
# 1823           NaN            9.8            4.0  ...                11.1
# 1824           NaN           11.6            9.2  ...                 7.6
# 1825           NaN           10.7            4.1  ...                10.6
#
#       Cool Deg Days (°C)  Total Rain (mm)  Total Snow (cm)  Total Precip (mm)  \
# 365                  0.0              NaN              NaN                0.2
# 366                  0.0              NaN              NaN                0.0
# 367                  0.0              NaN              NaN                0.0
# 368                  0.0              NaN              NaN                1.5
# 369                  0.0              NaN              NaN                5.6
# ...                  ...              ...              ...                ...
# 1821                 0.0              NaN              NaN                0.0
# 1822                 0.0              NaN              NaN                0.0
# 1823                 0.0              NaN              NaN                0.0
# 1824                 0.0              NaN              NaN                9.6
# 1825                 0.0              NaN              NaN               22.5
#
#       Snow on Grnd (cm)  Dir of Max Gust (10s deg)  Spd of Max Gust (km/h)  \
# 365                 1.0                        NaN                     NaN
# 366                 1.0                        NaN                     NaN
# 367                 1.0                        NaN                     NaN
# 368                 2.0                        NaN                     NaN
# 369                 2.0                        NaN                     NaN
# ...                 ...                        ...                     ...
# 1821                0.0                        NaN                     NaN
# 1822                NaN                        NaN                     NaN
# 1823                0.0                        NaN                     NaN
# 1824                0.0                        NaN                     NaN
# 1825                0.0                        NaN                     NaN
#
#       Season gardens_funded
# 365   Winter             33
# 366   Winter             33
# 367   Winter             33
# 368   Winter             33
# 369   Winter             33
# ...      ...            ...
# 1821  Winter             40
# 1822  Winter             40
# 1823  Winter             40
# 1824  Winter             40
# 1825  Winter             40
#
# [1461 rows x 21 columns]

# %%
# Correlation matrix between weather variables and gardens funded
corr_matrix = merged_df[['Mean Temp (°C)', 'Total Precip (mm)', 'gardens_funded']].corr()

print(corr_matrix)
# Out:
#                    Mean Temp (°C)  Total Precip (mm)  gardens_funded
# Mean Temp (°C)           1.000000           0.018685       -0.005620
# Total Precip (mm)        0.018685           1.000000        0.003762
# gardens_funded          -0.005620           0.003762        1.000000

# %%
# Shift weather data by one year
merged_df['lagged_avg_temp'] = merged_df['Mean Temp (°C)'].shift(1)
merged_df['lagged_total_precipitation'] = merged_df['Total Precip (mm)'].shift(1)

# Calculate correlation with lagged weather
lagged_corr = merged_df[['lagged_avg_temp', 'lagged_total_precipitation', 'gardens_funded']].corr()

print(lagged_corr)
# Out:
#                             lagged_avg_temp  lagged_total_precipitation  \
# lagged_avg_temp                    1.000000                    0.019611
# lagged_total_precipitation         0.019611                    1.000000
# gardens_funded                    -0.005737                    0.001702
#
#                             gardens_funded
# lagged_avg_temp                  -0.005737
# lagged_total_precipitation        0.001702
# gardens_funded                    1.000000

# %%
# Scatter plot for gardens funded vs average temperature
plt.figure(figsize=(8, 6))
plt.scatter(merged_df['Mean Temp (°C)'], merged_df['gardens_funded'], color='orange')
plt.xlabel('Average Temperature (°C)')
plt.ylabel('Gardens Funded')
plt.title('Gardens Funded vs Average Temperature')
plt.grid(True)
plt.show()

# Scatter plot for gardens funded vs total precipitation
plt.figure(figsize=(8, 6))
plt.scatter(merged_df['Total Precip (mm)'], merged_df['gardens_funded'], color='blue')
plt.xlabel('Total Precipitation (mm)')
plt.ylabel('Gardens Funded')
plt.title('Gardens Funded vs Total Precipitation')
plt.grid(True)
plt.show()

# %%
# Create a heatmap of the correlation matrix
plt.figure(figsize=(8, 6))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', fmt='.2f')
plt.title('Correlation Heatmap')
plt.show()
